# %% [markdown]
# # Capstone 2. Data cleaning & storytelling
#
# July, 2018
# ***
#
#
# **Objective:** As I mentioned in the proposal, the major goal of this capstone project is to help job seekers, especially those new graduates with not previous job experience, find their dream job based on their answers to our questionnaire. Because extensive web scrap is perhibited in those major job posting website such as Linkedin and indeed, I chose an job description data set from Kaggle.com. Data source: [kaggle dataset](https://www.kaggle.com/PromptCloudHQ/us-jobs-on-monstercom)
#
# Questionnaire will cover those aspects:
# - Industry
# - Location
# - Culture
#
# Each aspect need the user a number indicating the level of the importance.
#
# And finally, we will do a matching between job descriptions and the answer of the questionnaire.
# ***
# *For example: *
#
# I may answer the questionnaire in this way:
#
# - Industry = art; artificial intelligence. Weight = 40%
# - Location = big cities; eastern coast. Weight = 20%
# - Culture = innovation; big company. Weight = 40%
#
# And I hope to get job recommendations from this project.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
from collections import Counter
from tqdm import tqdm
import nltk
from time import sleep
import math
import seaborn as sns

plt.style.use('fivethirtyeight')

# %% [markdown]
# # Section 1: The dataset

# %%
# import the dataset and see how it looks like
df = pd.read_csv('monster_com-job_sample 2.csv')

# some basic inforamtion
print('There are {:d} job decriptions in the dataset.'.format(df.shape[0]))
print('The jobs are located in those country: ', df.country_code.unique().item())
print('{:d} out of 22000 job descriptions are tagged with a salary'.format(22000-sum(df.salary.isnull())))
# Out:
# There are 22000 job decriptions in the dataset.
# The jobs are located in those country:  US
# 3446 out of 22000 job descriptions are tagged with a salary

# %%
# drop columns that are not helpful for the following analysis
df = df.drop(df.columns[[0,1,2,3,4,7,10,11,12,13]],axis=1)
df.head()
# Out:
#                                      job_description  \
# 0  TeamSoft is seeing an IT Support Specialist to...
# 1  The Wisconsin State Journal is seeking a flexi...
# 2  Report this job About the Job DePuy Synthes Co...
# 3  Why Join Altec? If you’re considering a career...
# 4  Position ID#  76162 # Positions  1 State  CT C...
#
#                                            job_title  \
# 0               IT Support Technician Job in Madison
# 1            Business Reporter/Editor Job in Madison
# 2  Johnson & Johnson Family of Companies Job Appl...
# 3                    Engineer - Quality Job in Dixon
# 4       Shift Supervisor - Part-Time Job in Camphill
#
#                                             location  \
# 0                                  Madison, WI 53702
# 1                                  Madison, WI 53708
# 2  DePuy Synthes Companies is a member of Johnson...
# 3                                          Dixon, CA
# 4                                       Camphill, PA
#
#                       organization
# 0                              NaN
# 1          Printing and Publishing
# 2  Personal and Household Services
# 3                 Altec Industries
# 4                           Retail

# %% [markdown]
# In this dataset, we kept those columns which would be useful in the following sections.
#  - The **job_description** and **job_title** will be used to match industry.
#  - **organization** will be used for finding the name of that company and the culture of it.
#  - **location**, will be used to calculate distance, as well as finding out if the job located at big or small city, with increasing or declining population and so on.

# %% [markdown]
# # Section 2: Location
#
# ### Extract the location information: zip code, state, city
# Notice that this dataset is not cleaned. The locations have different format so that we need to extract that information use some technology such as regular expression.

# %%
# extract zip code information from the location column
# extract state information from the location column
p = re.compile(r'(?<![A-Z])[A-Z]{2}(?![A-Z])')
for i, row in df.iterrows():
    # add the column zip code
    ls = []
    for char in row.location:
        if char.isdigit():
            ls.append(char)
    if len(ls) == 5:
        df.set_value(i,'zip_code', ''.join(ls))
    
    # add the column state
    str_location = row.location
   
    if len(str_location) < 100 and len(str_location) > 1:
        state = p.search(str_location)
        if state is not None:
            df.set_value(i, 'state', state.group())
            ls = str_location.split(',')
            df.set_value(i, 'city', ls[0])
df.head()
# Out:
#                                      job_description  \
# 0  TeamSoft is seeing an IT Support Specialist to...
# 1  The Wisconsin State Journal is seeking a flexi...
# 2  Report this job About the Job DePuy Synthes Co...
# 3  Why Join Altec? If you’re considering a career...
# 4  Position ID#  76162 # Positions  1 State  CT C...
#
#                                            job_title  \
# 0               IT Support Technician Job in Madison
# 1            Business Reporter/Editor Job in Madison
# 2  Johnson & Johnson Family of Companies Job Appl...
# 3                    Engineer - Quality Job in Dixon
# 4       Shift Supervisor - Part-Time Job in Camphill
#
#                                             location  \
# 0                                  Madison, WI 53702
# 1                                  Madison, WI 53708
# 2  DePuy Synthes Companies is a member of Johnson...
# 3                                          Dixon, CA
# 4                                       Camphill, PA
#
#                       organization zip_code state      city
# 0                              NaN    53702    WI   Madison
# 1          Printing and Publishing    53708    WI   Madison
# 2  Personal and Household Services      NaN   NaN       NaN
# 3                 Altec Industries      NaN    CA     Dixon
# 4                           Retail      NaN    PA  Camphill

# %% [markdown]
# ### Dataset exploration 1: look at locations that have the biggest number of jobs

# %%
df_dropna = df[~df.state.isnull()]
print('There are %d jobs that shows which City they located at.' % len(df_dropna))

data = df_dropna.groupby('city').count().job_description.sort_values(ascending = False)[:15]
df_data = data.to_frame()
df_data['city'] = df_data.index
df_data.columns = ['Jobs Available', 'City']

g = sns.barplot(x='City', y='Jobs Available', data=df_data)
g.set_xticklabels(g.get_xticklabels(), rotation=90);
# Out:
# There are 19194 jobs that shows which City they located at.

# %%
data = df_dropna.groupby('state').count().job_description.sort_values(ascending = False)[:10]
print('There are %d jobs that shows which State they located at.' % len(df_dropna))
df_data = data.to_frame()
df_data['State'] = df_data.index
df_data.columns = ['Jobs Available', 'State']

g = sns.barplot(x='State', y='Jobs Available', data=df_data)
g.set_xticklabels(g.get_xticklabels(), rotation=90);
# Out:
# There are 19194 jobs that shows which State they located at.

# %% [markdown]
# ### Dataset exploration 2: save the DataFrame as excel and mapping the data in the USA map.

# %% [raw]
# # Create a Pandas Excel writer using XlsxWriter as the engine.
# writer = pd.ExcelWriter('monster_zipcode.xlsx', engine='xlsxwriter')
#
# # Convert the dataframe to an XlsxWriter Excel object.
# df.to_excel(writer, sheet_name='Sheet1')
#
# # Close the Pandas Excel writer and output the Excel file.
# writer.save()

# %%
df_dropna_zip = df[~df.zip_code.isnull()]
print('There are %d jobs that shows which zip_code they located at.' % len(df_dropna_zip))
# Out:
# There are 12059 jobs that shows which zip_code they located at.

# %% [markdown]
# ![map](map.png)
#
# https://plot.ly/python/bubble-maps/

# %%
df_dropna_zip.head()
# Out:
#                                       job_description  \
# 0   TeamSoft is seeing an IT Support Specialist to...
# 1   The Wisconsin State Journal is seeking a flexi...
# 7   RESPONSIBILITIES:Kforce has a client seeking a...
# 8   Part-Time, 4:30 pm - 9:30 pm, Mon - Fri Brookd...
# 10  Aflac Insurance Sales Agent While a career in ...
#
#                                         job_title              location  \
# 0            IT Support Technician Job in Madison     Madison, WI 53702
# 1         Business Reporter/Editor Job in Madison     Madison, WI 53708
# 7                    Mailroom Clerk Job in Austin      Austin, TX 73301
# 8                       Housekeeper Job in Austin      Austin, TX 78746
# 10  Aflac Insurance Sales Agent Job in Berryville  Berryville, VA 22611
#
#                                          organization zip_code state  \
# 0                                                 NaN    53702    WI
# 1                             Printing and Publishing    53708    WI
# 7                                                 NaN    73301    TX
# 8   Hotels and Lodging Personal and Household Serv...    78746    TX
# 10                                          Insurance    22611    VA
#
#           city  distance_home
# 0      Madison      22.534463
# 1      Madison      22.534463
# 7       Austin      17.519130
# 8       Austin      17.499082
# 10  Berryville      33.909870

# %%
# this panda series contains the number of jobs in each zip code
data = df_dropna_zip.groupby('zip_code').count().job_description.sort_values(ascending = False)

# %% [markdown]
# ### Determine the location index.
# Location index is determined by the distance from where the job is and where the job seeker currently located. The index is also determined by the quality of the location. People may care different things about the location, such as the population, safety, near big city, near national park, city or country, art, education and so on. We can put all those factors in the questionnaire. This location index can be very complex and it would be impossible to complete in a short time. We'll simplify the calculation by picking 1 or 2 factors, like distance from home and population.
#
#
# ————note:
# give a new map that shows the index of the locations.

# %%
# calculate distance based on zip code
from pyzipcode import ZipCodeDatabase

zcdb = ZipCodeDatabase()
zipcode = zcdb[84112]
lan_home = zipcode.latitude
lon_home = zipcode.longitude

df_zip = df[df['zip_code'].notnull()]
df_zip = df_zip[~(df_zip['zip_code']=='00000')]

for i, row in df_zip.iterrows():
    #calculate distance
    try:
        zipcode = zcdb[row.zip_code]
        lan = zipcode.latitude
        lon = zipcode.longitude
        distance = math.sqrt((lan-lan_home)**2+(lon-lon_home)**2)
        df.set_value(i, 'distance_home', distance)
    except:
        pass

# %%
df_zip.shape
# Out:
# (12054, 8)

# %%
df_zip
# Out:
#                                          job_description  \
# 0      TeamSoft is seeing an IT Support Specialist to...
# 1      The Wisconsin State Journal is seeking a flexi...
# 7      RESPONSIBILITIES:Kforce has a client seeking a...
# 8      Part-Time, 4:30 pm - 9:30 pm, Mon - Fri Brookd...
# 10     Aflac Insurance Sales Agent While a career in ...
# 13     Launch your teaching career with the Leader in...
# 15     CenturyLink (NYSE: CTL) is a global communicat...
# 16     Airfields. Roads. Dams. Buildings. Name the pr...
# 19     Competitive compensation package, excellent co...
# 21     Job Summary:Responsible for rendering decision...
# 22     We're looking for team players to provide cons...
# 23      Well respected, rapidly growing, and expandin...
# 25     ENGINEERING Biomedical Engineering Director. D...
# 27     The Training Department plays a crucial role i...
# 30     The world's largest standalone medical technol...
# 32     Seeking individual with 5+ years experience de...
# 33     Construction                                  ...
# 34     General DescriptionAn Associate Product Develo...
# 37     Duties The BPMI Quality Engineer: Analyzes the...
# 39     ResponsibilitiesCandidate will participate in ...
# 40     Management Apprenticeship ProgramGetting paid ...
# 42     Job Description:JOB SUMMARYThe Office Administ...
# 43     A Surveyor Assistant is needed for a leading e...
# 44     We're looking for team players to provide cons...
# 46     Adolfson & Peterson (AP), one of the nation’s ...
# 47     The Project Manager reports directly to the Co...
# 48      Accounts Receivable (Commercial Real Estate) ...
# 49     Job Title: Technical Writer Location: Franklin...
# 50     Palgrave Macmillan is a global academic publis...
# 51     Ebert Engineering Inc.currently has an opening...
# ...                                                  ...
# 21955  Title: Senior Accountant Job in Chicago, IL  O...
# 21956    Company Overview: XPO provides cutting-edge ...
# 21959  Senior Project Manager - Commercial Constructi...
# 21960  Senior Accountant Position in Chicago If you a...
# 21961  LIFEGUARD in Cincinnati, Ohio*TriHealth Fitnes...
# 21964  Bookkeeper Chicago, ILPay rate 15.00-19.00Expe...
# 21965    Sales Associate Description Job Summary: Luc...
# 21966   PRODUCTION SPECIALIST PRIMARY FUNCTIONS: The ...
# 21968  Securities Litigation Associate; Chicago, IL  ...
# 21969  The Package Development Engineering Contractor...
# 21973  RESPONSIBILITIES:Kforce has a client in Cincin...
# 21974  We are looking to recruit a motivated individu...
# 21975  McCormick & Company, Incorporated, a global le...
# 21977  About the JobWhat is more secure than the repl...
# 21978  We're excited to be hosting our Saturday hirin...
# 21979  •             Overall 6-10 years of IT experie...
# 21982  If you are interested in this senior accountan...
# 21984  Now Hiring Data Entry Reps and Mail Clerks- ca...
# 21986  About Us:Kemper at a glanceWith $8 billion in ...
# 21987  Own Your TerritoryAsk yourself these questions...
# 21988  RESPONSIBILITIES:                             ...
# 21989  Title: Accounts Receivable Specialist Our clie...
# 21990  To apply to this Finance Manager role in Chica...
# 21991  Full-Time Amber Park Cincinnati, OH 3801 East ...
# 21992  Sales Management TraineeLooking to use your sk...
# 21993  We are looking to recruit a personal individua...
# 21994  What The Job Is AboutSales Support Representat...
# 21996  Luxury homebuilder in Cincinnati seeking multi...
# 21997  RE: Adobe AEM-          Client -          Loca...
# 21998  Jernberg Industries was established in 1937 an...
#
#                                                job_title  \
# 0                   IT Support Technician Job in Madison
# 1                Business Reporter/Editor Job in Madison
# 7                           Mailroom Clerk Job in Austin
# 8                              Housekeeper Job in Austin
# 10         Aflac Insurance Sales Agent Job in Berryville
# 13     Primrose Private Preschool Teacher Job in Houston
# 15     Engineer II - Outside Plant Engineer Job in De...
# 16     Horizontal Construction Engineers Job in Wades...
# 19     Technician - Robot & Multi-Axis CNC Field Serv...
# 21            Real Estate Underwriter -Jr Job in Houston
# 22     Combat Engineer - Construction and Engineering...
# 23                Estimator - Construction Job in Denver
# 25     Biomedical Engineering Director Job in San Carlos
# 27     Traveling Customer Training Professional Job i...
# 30     Mechanical Engineer - FEA/Mechanical Modeling/...
# 32     Machine Control Systems Engineer - BSEE Job in...
# 33                      Equipment Operator Job in Denver
# 34        Associate Product Developer Job in Saint Louis
# 37                   Quality Engineer Job in Monroeville
# 39     Software Engineer - Display Solutions Group Jo...
# 40      Management Apprenticeship Program Job in Houston
# 42                  Office Administrator - Job in Denver
# 43     Surveyor - Trimble /Field Link /Construction J...
# 44     Combat Engineer - Construction and Engineering...
# 46                    Project Engineer- CO Job in Aurora
# 47                  Project Manager ( Z ) Job in Houston
# 48     Accounts Receivable - Commercial Real Estate J...
# 49                Technical Writer Job in Franklin Lakes
# 50                                  Commissioning Editor
# 51     Water and Wastewater Design Engineer Job in Sk...
# ...                                                  ...
# 21955                   Senior Accountant Job in Chicago
# 21956                Account Executive Job in Cincinnati
# 21959  Senior Project Manager - Commercial Constructi...
# 21960                   Senior Accountant Job in Chicago
# 21961                        Lifeguard Job in Cincinnati
# 21964                          Bookkeeper Job in Chicago
# 21965  Executive Recruiter/Sales Consultant Job in Ci...
# 21966  Production Specialist – Mortgage Loan Processo...
# 21968     Securities Litigation Associate Job in Chicago
# 21969        Packaging Design Engineer Job in Cincinnati
# 21973  Accounts Payable Accounting Manager Job in Cin...
# 21974  Medical Collections Representative Job in Chicago
# 21975        Customer Business Manager Job in Cincinnati
# 21977     Outside Sales Representative Job in Cincinnati
# 21978              Cincinnati Job Fair Job in Cincinnati
# 21979        Enterprise Search Analyst Job in Cincinnati
# 21982  Senior Accountant for a Digital Publisher in t...
# 21984  Now Hiring Data Entry Reps and Mail Clerks- ca...
# 21986                       Audit Manager Job in Chicago
# 21987                        Experienced Territory Sales
# 21988                       Accountant Job in Cincinnati
# 21989      Accounts Receivable Specialist Job in Chicago
# 21990                     Finance Manager Job in Chicago
# 21991     Licensed Practical Nurse LPN Job in Cincinnati
# 21992  Customer Service Professionals Consider a Care...
# 21993       Patient Access Representative Job in Chicago
# 21994  Immediate Customer Service Position Job in Cin...
# 21996                       Accountant Job in Cincinnati
# 21997                    AEM/CQ developer Job in Chicago
# 21998  Electrician - Experienced Forging Electrician ...
#
#                        location  \
# 0             Madison, WI 53702
# 1             Madison, WI 53708
# 7              Austin, TX 73301
# 8              Austin, TX 78746
# 10         Berryville, VA 22611
# 13            Houston, TX 77098
# 15         Des Moines, IA 50317
# 16              Wadesboro 28170
# 19        Carter Lake, IA 51510
# 21            Houston, TX 77027
# 22               La Porte 46350
# 23             Denver, CO 80215
# 25         San Carlos, CA 94070
# 27            Houston, TX 77040
# 30        Mounds View, MN 55112
# 32             Aurora, IL 60502
# 33             Denver, CO 80202
# 34        Saint Louis, MO 63116
# 37        Monroeville, PA 15146
# 39              Tulsa, OK 74146
# 40            Houston, TX 77040
# 42             Denver, CO 80237
# 43            Houston, TX 77001
# 44           Bradford, Vt 05033
# 46             Aurora, CO 80011
# 47            Houston, TX 77034
# 48             Denver, CO 80202
# 49     Franklin Lakes, NJ 07417
# 50           New York, NY 10013
# 51           Skippack, PA 19474
# ...                         ...
# 21955         Chicago, IL 60603
# 21956      Cincinnati, OH 45201
# 21959      Cincinnati, OH 45206
# 21960         Chicago, IL 60603
# 21961      Cincinnati, OH 45242
# 21964         Chicago, IL 60602
# 21965      Cincinnati, OH 45202
# 21966     Day Heights, OH 45150
# 21968         Chicago, IL 60603
# 21969      Cincinnati, OH 45242
# 21973      Cincinnati, OH 45202
# 21974         Chicago, IL 60603
# 21975      Cincinnati, OH 45202
# 21977      Cincinnati, OH 45202
# 21978      Cincinnati, OH 45226
# 21979      Cincinnati, OH 45202
# 21982         Chicago, IL 60603
# 21984      Cincinnati, OH 45214
# 21986         Chicago, IL 60601
# 21987         Chicago, IL 60602
# 21988      Cincinnati, OH 45249
# 21989         Chicago, IL 60603
# 21990         Chicago, IL 60603
# 21991      Cincinnati, OH 45236
# 21992      Cincinnati, OH 45237
# 21993         Chicago, IL 60603
# 21994      Cincinnati, OH 45202
# 21996      Cincinnati, OH 45236
# 21997         Chicago, IL 60602
# 21998         Chicago, IL 60609
#
#                                             organization zip_code state  \
# 0                                                    NaN    53702    WI
# 1                                Printing and Publishing    53708    WI
# 7                                                    NaN    73301    TX
# 8      Hotels and Lodging Personal and Household Serv...    78746    TX
# 10                                             Insurance    22611    VA
# 13                                             Education    77098    TX
# 15                                                   NaN    50317    IA
# 16                                                   NaN    28170   NaN
# 19                                                   NaN    51510    IA
# 21                      Accounting and Auditing Services    77027    TX
# 22                                                   NaN    46350   NaN
# 23                                                   NaN    80215    CO
# 25                                  Engineering Services    94070    CA
# 27              AllComputer SoftwareComputer/IT Services    77040    TX
# 30                                                   NaN    55112    MN
# 32                                                   NaN    60502    IL
# 33                                                   NaN    80202    CO
# 34                                 Manufacturing - Other    63116    MO
# 37                                 Aerospace and Defense    15146    PA
# 39                                 Manufacturing - Other    74146    OK
# 40     Advertising and PR ServicesManagement Consulti...    77040    TX
# 42                                  Other/Not Classified    80237    CO
# 43                                                   NaN    77001    TX
# 44                                                   NaN    05033   NaN
# 46        Construction - Residential & Commercial/Office    80011    CO
# 47                                                   NaN    77034    TX
# 48                                                   NaN    80202    CO
# 49                                                   NaN    07417    NJ
# 50                               Printing and Publishing    10013    NY
# 51                                  Engineering Services    19474    PA
# ...                                                  ...      ...   ...
# 21955                                                NaN    60603    IL
# 21956                                                NaN    45201    OH
# 21959     Construction - Residential & Commercial/Office    45206    OH
# 21960                                                NaN    60603    IL
# 21961                                Healthcare Services    45242    OH
# 21964                   Accounting and Auditing Services    60602    IL
# 21965                       Staffing/Employment Agencies    45202    OH
# 21966                                                NaN    45150    OH
# 21968                                     Legal Services    60603    IL
# 21969  Industrial/Manufacturing EngineeringGeneral/Ot...    45242    OH
# 21973                                                NaN    45202    OH
# 21974                                                NaN    60603    IL
# 21975                       Food and Beverage Production    45202    OH
# 21977   AllEnergy and UtilitiesBusiness Services - Other    45202    OH
# 21978                               Other/Not Classified    45226    OH
# 21979                                  Internet Services    45202    OH
# 21982                                                NaN    60603    IL
# 21984                               Other/Not Classified    45214    OH
# 21986                                                NaN    60601    IL
# 21987                                                NaN    60602    IL
# 21988                                Healthcare Services    45249    OH
# 21989                                                NaN    60603    IL
# 21990                                                NaN    60603    IL
# 21991           Healthcare Services Other/Not Classified    45236    OH
# 21992                                                NaN    45237    OH
# 21993                                                NaN    60603    IL
# 21994                                                All    45202    OH
# 21996     Construction - Residential & Commercial/Office    45236    OH
# 21997                                                NaN    60602    IL
# 21998                          Jernberg Industries, Inc.    60609    IL
#
#                  city  distance_home
# 0             Madison      22.534463
# 1             Madison      22.534463
# 7              Austin      17.519130
# 8              Austin      17.499082
# 10         Berryville      33.909870
# 13            Houston      19.788289
# 15         Des Moines      18.330247
# 16                NaN      32.293089
# 19        Carter Lake      15.934904
# 21            Houston      19.757337
# 22                NaN      25.146417
# 23             Denver       6.816510
# 25         San Carlos      10.927524
# 27            Houston      19.614342
# 30        Mounds View      19.145215
# 32             Aurora      23.600692
# 33             Denver       6.920801
# 34        Saint Louis      21.688096
# 37        Monroeville      32.079769
# 39              Tulsa      16.653961
# 40            Houston      19.614342
# 42             Denver       7.031820
# 43            Houston      19.829807
# 44                NaN      39.831262
# 46             Aurora       7.099931
# 47            Houston      20.001174
# 48             Denver       6.920801
# 49     Franklin Lakes      37.629779
# 50           New York      37.837830
# 51           Skippack      36.441213
# ...               ...            ...
# 21955         Chicago      24.237410
# 21956      Cincinnati      27.348890
# 21959      Cincinnati      27.404057
# 21960         Chicago      24.237410
# 21961      Cincinnati      27.536849
# 21964         Chicago      24.233956
# 21965      Cincinnati      27.388573
# 21966     Day Heights      27.653637
# 21968         Chicago      24.237410
# 21969      Cincinnati      27.536849
# 21973      Cincinnati      27.388573
# 21974         Chicago      24.237410
# 21975      Cincinnati      27.388573
# 21977      Cincinnati      27.388573
# 21978      Cincinnati      27.458629
# 21979      Cincinnati      27.388573
# 21982         Chicago      24.237410
# 21984      Cincinnati      27.339174
# 21986         Chicago      24.248075
# 21987         Chicago      24.233956
# 21988      Cincinnati      27.550285
# 21989         Chicago      24.237410
# 21990         Chicago      24.237410
# 21991      Cincinnati      27.489367
# 21992      Cincinnati      27.427725
# 21993         Chicago      24.237410
# 21994      Cincinnati      27.388573
# 21996      Cincinnati      27.489367
# 21997         Chicago      24.233956
# 21998         Chicago      24.209512
#
# [12054 rows x 8 columns]

# %% [markdown]
# There are 12054 jobs in the dataset that has the distance information calcuated from zip code.

# %% [markdown]
# Population is an important aspect when investigating a location. First, the larger the population in that area means that it's more like a city area instead of an rural area. Second, we can also monitor the change of the population. If there is an increase of population, it may indicate that that area have a good amount job opportunity and overall healthy economy. I use this data source: [US Population By Zip Code
# For both 2000 and 2010](https://www.kaggle.com/census/us-population-by-zip-code#population_by_zip_2000.csv)

# %%
# load the dataset
df_zip_2000 = pd.read_csv('us-population-by-zip-code/population_by_zip_2000.csv')
df_zip_2010 = pd.read_csv('us-population-by-zip-code/population_by_zip_2010.csv')

# %%
# sum up the population in a zipcode area
df_2010 = df_zip_2010.groupby('zipcode').sum()['population'].to_frame()
df_2000 = df_zip_2000.groupby('zipcode').sum()['population'].to_frame()
df_2000['zip'] = df_2000.index
df_2010['zip'] = df_2010.index

# %%
for i in df_2000:
    print(i)
# Out:
# population
# zip

# %%
pd.merge(df_2000, df_2010, on='zip', how = 'right')
# Out:
#        population_x    zip  population_y
# 0               NaN    602        124560
# 1               NaN    603        164067
# 2               NaN    606         19845
# 3               NaN    610         87048
# 4               NaN    612        201030
# 5               NaN    616         33051
# 6               NaN    617         73791
# 7               NaN    622         23559
# 8               NaN    623        129183
# 9               NaN    624         78723
# 10              NaN    627        105477
# 11              NaN    631          5556
# 12              NaN    637         75861
# 13              NaN    638         56823
# 14              NaN    641         93573
# 15              NaN    646        114597
# 16              NaN    647         18516
# 17              NaN    650         44994
# 18              NaN    652         14145
# 19              NaN    653         39921
# 20              NaN    656         64443
# 21              NaN    659        125859
# 22              NaN    660         51750
# 23              NaN    662        129846
# 24              NaN    664         50352
# 25              NaN    667         77904
# 26              NaN    669         89232
# 27              NaN    670         29421
# 28              NaN    674        133371
# 29              NaN    676        120948
# ...             ...    ...           ...
# 33089           NaN  99786           777
# 33090           NaN  99788           207
# 33091           NaN  99789          1206
# 33092           NaN  99790            60
# 33093           NaN  99791           711
# 33094           NaN  99801         87492
# 33095           NaN  99820          1437
# 33096           NaN  99824          6333
# 33097           NaN  99825           360
# 33098           NaN  99826          1326
# 33099           NaN  99827          7806
# 33100           NaN  99829          2331
# 33101           NaN  99830          1683
# 33102           NaN  99832           312
# 33103           NaN  99833          9606
# 33104           NaN  99835         26640
# 33105           NaN  99836           156
# 33106           NaN  99840          2904
# 33107           NaN  99841           399
# 33108           NaN  99901         40524
# 33109           NaN  99903            93
# 33110           NaN  99918           693
# 33111           NaN  99919          1593
# 33112           NaN  99921          5760
# 33113           NaN  99922          1152
# 33114           NaN  99923           261
# 33115           NaN  99925          2457
# 33116           NaN  99926          4380
# 33117           NaN  99927           282
# 33118           NaN  99929          7014
#
# [33119 rows x 3 columns]

# %% [markdown]
# # Section 3: Culture
#
# In this section, we're trying to judge the culture of a company by the size of the company as well as some key adjectives in the job descriptions, such as "flexible", "motivated", "innovative" and so on.
#
#
# ### Step 1: extract company information
# We want to extract company information, which means we get the name of the company, and we can find out more about the company by google it. When we want to know about a company, we look at several things, like the size of the company, the history of the company, the review of the company as well as if I have networks in there. The same as the previous location section, it can be a big task to complete all the factors we can think of. But I will pick up a few for practice, such as the size of the company.
#
# In this dataset, it's a little challenging to get the company name because the company name is not clearly marked in the dataset.
#
# The company name is usually associated with key words like "seek", "join". But still, this not always the case. And from the first job description, the word "seeking" was misspelled as "seeing".

# %%
# Let's look at an example: 
sample = df.job_description[2]

# %% [markdown]
# From the above example:
#
# The company we may want extract is "The Wisconsin State Journal". "to lead its three-person business desk", even I have no idea what does that mean. This maybe confusion that "three people" sounds like a startup company, but actually not.

# %% [markdown]
# After extracting the company information, we would like to link with another dataset that includes the information of major companies.

# %%
import nltk

sentence = sample
tokens = nltk.word_tokenize(sentence)

tagged = nltk.pos_tag(tokens)
tagged

# %% [markdown]
# ### Step 2: extract the adjectives from the job description.

# %% [markdown]
# ## I. extract keywords from a text:
# 3. parsing the text, find out nouns and adjectives.
# 1. remove stopwords
# 2. word stemming
#
# 4. rank the nouns and adjectives by the relavent of the job seeking
#
# ## II. vectorize the keywords of each job description

# %%
adj = [x[0] for x in tagged if x[1] == 'JJ']
noun = [x[0] for x in tagged if x[1] == 'NN' or x[1]=='NNS']

# %%
# remove stopword
fh = open('english.stop.txt','r')
ls_stopword = []
for item in fh:
    ls_stopword.append(item.rstrip('\n'))
                       
adj_removed = [x for x in adj if x not in ls_stopword]
noun_removed = [x for x in noun if x not in ls_stopword]

# remove symbols
ls_symbols = ['[',']','<','>','%',' ', '•', 'null', 'x', '$', '+']
                       
adj_removed = [x for x in adj if x not in ls_symbols]
noun_removed = [x for x in noun if x not in ls_symbols]

# %%
c_noun = Counter(noun_removed)

# %%
c_adj = Counter(adj_removed)

# %%
c_noun = Counter(noun_removed)
c_noun.most_common(10)

# %%
# count all of the jobs
adj_all = []
noun_all = []

for i in tqdm(range(len(df))):
    sample = df.job_description[i]
    
    sentence = sample
    tokens = nltk.word_tokenize(sentence)
    tagged = nltk.pos_tag(tokens)
    
    adj = [x[0] for x in tagged if x[1] == 'JJ']
    noun = [x[0] for x in tagged if x[1] == 'NN' or x[1]=='NNS']
    
    # remove stopword
    fh = open('english.stop.txt','r')
    ls_stopword = []
    for item in fh:
        ls_stopword.append(item.rstrip('\n'))

    adj_removed = [x for x in adj if x not in ls_stopword]
    noun_removed = [x for x in noun if x not in ls_stopword]

    # remove symbols
    ls_symbols = ['[',']','<','>','%',' ', '•', 'null', 'x', '$', '+', '*', '·','s']

    adj_removed = [x for x in adj if x not in ls_symbols]
    noun_removed = [x for x in noun if x not in ls_symbols]
    
    for item_adj in adj_removed:
        adj_all.append(item_adj)
    for item_noun in noun_removed:
        noun_all.append(item_noun)
    sleep(0.01)

# %%
c_noun_all = Counter(noun_all)
c_adj_all = Counter(adj_all)

# %%
c_noun_all.most_common(100)

# %%
c_adj_all.most_common(100)

# %% [markdown]
# # Section 4: Industry
#
# In this section, we're trying to get the industry information of the company. Industry such as sports, media, software, communication, devices, music, non-profit and so on. This information may found from those nouns of the job description. For example, from the job description example of Section 3, we may find "Journal", "reporter", "editor", "journalist", "trends" and so on may be a good represent of the industry of the company.
